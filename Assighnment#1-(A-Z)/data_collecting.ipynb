# %% [markdown]
# # Downloaded data from
# # https://www.kaggle.com/yairhadad1/cnn-for-handwritten-alphabets

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf

# %%
#os.listdir(".")

# %%
dataset = pd.read_csv("A_Z Handwritten Data/A_Z Handwritten Data.csv").astype('float32')
dataset.rename(columns={'0':'label'}, inplace=True)

# Splite data the X - Our data , and y - the prdict label
X = dataset.drop('label',axis = 1)
y = dataset['label']

# %%
print("shape:",X.shape)
print("culoms count:",len(X.iloc[1]))
print("784 = 28X28")
# Out:
# shape: (372450, 784)
# culoms count: 784
# 784 = 28X28

# %%
# making directories(folders)
base_dir = 'A_to_Z' 
os.mkdir(base_dir)                          
train_dir = os.path.join(base_dir, 'train')
os.mkdir(train_dir)                         
validation_dir = os.path.join(base_dir, 'validation')
os.mkdir(validation_dir)                    
test_dir = os.path.join(base_dir, 'test')
os.mkdir(test_dir)

# %%
# making sub directories

# %%
train_A_dir = os.path.join(train_dir, 'A') 
os.mkdir(train_A_dir)
train_B_dir = os.path.join(train_dir, 'B')
os.mkdir(train_B_dir)
train_C_dir = os.path.join(train_dir, 'C') 
os.mkdir(train_C_dir)
train_D_dir = os.path.join(train_dir, 'D')
os.mkdir(train_D_dir)
train_E_dir = os.path.join(train_dir, 'E') 
os.mkdir(train_E_dir)
train_F_dir = os.path.join(train_dir, 'F')
os.mkdir(train_F_dir)
train_G_dir = os.path.join(train_dir, 'G') 
os.mkdir(train_G_dir)
train_H_dir = os.path.join(train_dir, 'H')
os.mkdir(train_H_dir)
train_I_dir = os.path.join(train_dir, 'I') 
os.mkdir(train_I_dir)
train_J_dir = os.path.join(train_dir, 'J')
os.mkdir(train_J_dir)
train_K_dir = os.path.join(train_dir, 'K') 
os.mkdir(train_K_dir)
train_L_dir = os.path.join(train_dir, 'L')
os.mkdir(train_L_dir)
train_M_dir = os.path.join(train_dir, 'M') 
os.mkdir(train_M_dir)
train_N_dir = os.path.join(train_dir, 'N')
os.mkdir(train_N_dir)
train_O_dir = os.path.join(train_dir, 'O') 
os.mkdir(train_O_dir)
train_P_dir = os.path.join(train_dir, 'P')
os.mkdir(train_P_dir)
train_Q_dir = os.path.join(train_dir, 'Q') 
os.mkdir(train_Q_dir)
train_R_dir = os.path.join(train_dir, 'R')
os.mkdir(train_R_dir)
train_S_dir = os.path.join(train_dir, 'S') 
os.mkdir(train_S_dir)
train_T_dir = os.path.join(train_dir, 'T')
os.mkdir(train_T_dir)
train_U_dir = os.path.join(train_dir, 'U') 
os.mkdir(train_U_dir)
train_V_dir = os.path.join(train_dir, 'V')
os.mkdir(train_V_dir)
train_W_dir = os.path.join(train_dir, 'W') 
os.mkdir(train_W_dir)
train_X_dir = os.path.join(train_dir, 'X')
os.mkdir(train_X_dir)
train_Y_dir = os.path.join(train_dir, 'Y') 
os.mkdir(train_Y_dir)
train_Z_dir = os.path.join(train_dir, 'Z')
os.mkdir(train_Z_dir)

# %%
test_A_dir = os.path.join(test_dir, 'A') 
os.mkdir(test_A_dir)
test_B_dir = os.path.join(test_dir, 'B')
os.mkdir(test_B_dir)
test_C_dir = os.path.join(test_dir, 'C') 
os.mkdir(test_C_dir)
test_D_dir = os.path.join(test_dir, 'D')
os.mkdir(test_D_dir)
test_E_dir = os.path.join(test_dir, 'E') 
os.mkdir(test_E_dir)
test_F_dir = os.path.join(test_dir, 'F')
os.mkdir(test_F_dir)
test_G_dir = os.path.join(test_dir, 'G') 
os.mkdir(test_G_dir)
test_H_dir = os.path.join(test_dir, 'H')
os.mkdir(test_H_dir)
test_I_dir = os.path.join(test_dir, 'I') 
os.mkdir(test_I_dir)
test_J_dir = os.path.join(test_dir, 'J')
os.mkdir(test_J_dir)
test_K_dir = os.path.join(test_dir, 'K') 
os.mkdir(test_K_dir)
test_L_dir = os.path.join(test_dir, 'L')
os.mkdir(test_L_dir)
test_M_dir = os.path.join(test_dir, 'M') 
os.mkdir(test_M_dir)
test_N_dir = os.path.join(test_dir, 'N')
os.mkdir(test_N_dir)
test_O_dir = os.path.join(test_dir, 'O') 
os.mkdir(test_O_dir)
test_P_dir = os.path.join(test_dir, 'P')
os.mkdir(test_P_dir)
test_Q_dir = os.path.join(test_dir, 'Q') 
os.mkdir(test_Q_dir)
test_R_dir = os.path.join(test_dir, 'R')
os.mkdir(test_R_dir)
test_S_dir = os.path.join(test_dir, 'S') 
os.mkdir(test_S_dir)
test_T_dir = os.path.join(test_dir, 'T')
os.mkdir(test_T_dir)
test_U_dir = os.path.join(test_dir, 'U') 
os.mkdir(test_U_dir)
test_V_dir = os.path.join(test_dir, 'V')
os.mkdir(test_V_dir)
test_W_dir = os.path.join(test_dir, 'W') 
os.mkdir(test_W_dir)
test_X_dir = os.path.join(test_dir, 'X')
os.mkdir(test_X_dir)
test_Y_dir = os.path.join(test_dir, 'Y') 
os.mkdir(test_Y_dir)
test_Z_dir = os.path.join(test_dir, 'Z')
os.mkdir(test_Z_dir)

# %%
validation_A_dir = os.path.join(validation_dir, 'A') 
os.mkdir(validation_A_dir)
validation_B_dir = os.path.join(validation_dir, 'B')
os.mkdir(validation_B_dir)
validation_C_dir = os.path.join(validation_dir, 'C') 
os.mkdir(validation_C_dir)
validation_D_dir = os.path.join(validation_dir, 'D')
os.mkdir(validation_D_dir)
validation_E_dir = os.path.join(validation_dir, 'E') 
os.mkdir(validation_E_dir)
validation_F_dir = os.path.join(validation_dir, 'F')
os.mkdir(validation_F_dir)
validation_G_dir = os.path.join(validation_dir, 'G') 
os.mkdir(validation_G_dir)
validation_H_dir = os.path.join(validation_dir, 'H')
os.mkdir(validation_H_dir)
validation_I_dir = os.path.join(validation_dir, 'I') 
os.mkdir(validation_I_dir)
validation_J_dir = os.path.join(validation_dir, 'J')
os.mkdir(validation_J_dir)
validation_K_dir = os.path.join(validation_dir, 'K') 
os.mkdir(validation_K_dir)
validation_L_dir = os.path.join(validation_dir, 'L')
os.mkdir(validation_L_dir)
validation_M_dir = os.path.join(validation_dir, 'M') 
os.mkdir(validation_M_dir)
validation_N_dir = os.path.join(validation_dir, 'N')
os.mkdir(validation_N_dir)
validation_O_dir = os.path.join(validation_dir, 'O') 
os.mkdir(validation_O_dir)
validation_P_dir = os.path.join(validation_dir, 'P')
os.mkdir(validation_P_dir)
validation_Q_dir = os.path.join(validation_dir, 'Q') 
os.mkdir(validation_Q_dir)
validation_R_dir = os.path.join(validation_dir, 'R')
os.mkdir(validation_R_dir)
validation_S_dir = os.path.join(validation_dir, 'S') 
os.mkdir(validation_S_dir)
validation_T_dir = os.path.join(validation_dir, 'T')
os.mkdir(validation_T_dir)
validation_U_dir = os.path.join(validation_dir, 'U') 
os.mkdir(validation_U_dir)
validation_V_dir = os.path.join(validation_dir, 'V')
os.mkdir(validation_V_dir)
validation_W_dir = os.path.join(validation_dir, 'W') 
os.mkdir(validation_W_dir)
validation_X_dir = os.path.join(validation_dir, 'X')
os.mkdir(validation_X_dir)
validation_Y_dir = os.path.join(validation_dir, 'Y') 
os.mkdir(validation_Y_dir)
validation_Z_dir = os.path.join(validation_dir, 'Z')
os.mkdir(validation_Z_dir)

# %%
def A(train,test,validation):
    # total A from (0 to 13868)
    basee = 0
    pic_want = basee + train      # here type how many pic you want to copy for train data
    
    fname_start_from = 0
    pic_size = (28,28)
    dir_path = train_A_dir
    for i in range(basee,pic_want):
        plt.figure(figsize = (pic_size))
        plt.imshow(X.iloc[i].values.reshape(28,28),interpolation='nearest', cmap='Greys')
        filename = 'A.' + str(fname_start_from) +'.jpg'
        path = os.path.join(dir_path, filename)
        plt.savefig(path)
        plt.close()
        fname_start_from+=1

    basee =  pic_want # basee + pic_want
    pic_want = basee + test #test + train   # here type how many pic you want to copy for test data
    #print("base :",basee)
    #print("picwant :",pic_want)
    
    fname_start_from = 0
    pic_size = (28,28)
    dir_path = test_A_dir
    for i in range(basee,pic_want):
        plt.figure(figsize = (pic_size))
        plt.imshow(X.iloc[i].values.reshape(28,28),interpolation='nearest', cmap='Greys')
        filename = 'A.' + str(fname_start_from) +'.jpg'
        path = os.path.join(dir_path, filename)
        plt.savefig(path)
        plt.close()
        fname_start_from+=1

    basee =  pic_want # + pic_want
    pic_want = basee + validation #test + train + validation      # here type how many pic you want to copy for validation data
    #print("base :",basee)
    #print("picwant :",pic_want)
    
    fname_start_from = 0
    pic_size = (28,28)
    dir_path = validation_A_dir
    for i in range(basee,pic_want):
        plt.figure(figsize = (pic_size))
        plt.imshow(X.iloc[i].values.reshape(28,28),interpolation='nearest', cmap='Greys')
        filename = 'A.' + str(fname_start_from) +'.jpg'
        path = os.path.join(dir_path, filename)
        plt.savefig(path)
        plt.close()
        fname_start_from+=1

# %%
#train = 11
#test = 12           # 23
#validation = 13     # 36

#A(train,test,validation)

# %%
def B(train,test,validation):
    # total B from (13869 to 22536)
    basee = 13869
    pic_want = basee + train      # here type how many pic you want to copy for train data
    #print("base :",basee)
    #print("picwant :",pic_want)
    
    fname_start_from = 0
    pic_size = (28,28)
    dir_path = train_B_dir
    for i in range(basee,pic_want):
        plt.figure(figsize = (pic_size))
        plt.imshow(X.iloc[i].values.reshape(28,28),interpolation='nearest', cmap='Greys')
        filename = 'B.' + str(fname_start_from) +'.jpg'
        path = os.path.join(dir_path, filename)
        plt.savefig(path)
        plt.close()
        fname_start_from+=1

    basee =  pic_want # basee + pic_want
    pic_want = basee + test   # here type how many pic you want to copy for test data
    #print("base :",basee)
    #print("picwant :",pic_want)
    
    fname_start_from = 0
    pic_size = (28,28)
    dir_path = test_B_dir
    for i in range(basee,pic_want):
        plt.figure(figsize = (pic_size))
        plt.imshow(X.iloc[i].values.reshape(28,28),interpolation='nearest', cmap='Greys')
        filename = 'B.' + str(fname_start_from) +'.jpg'
        path = os.path.join(dir_path, filename)
        plt.savefig(path)
        plt.close()
        fname_start_from+=1

    basee =  pic_want # + pic_want
    pic_want = basee + validation      # here type how many pic you want to copy for validation data
    #print("base :",basee)
    #print("picwant :",pic_want)
    
    fname_start_from = 0
    pic_size = (28,28)
    dir_path = validation_B_dir
    for i in range(basee,pic_want):
        plt.figure(figsize = (pic_size))
        plt.imshow(X.iloc[i].values.reshape(28,28),interpolation='nearest', cmap='Greys')
        filename = 'B.' + str(fname_start_from) +'.jpg'
        path = os.path.join(dir_path, filename)
        plt.savefig(path)
        plt.close()
        fname_start_from+=1

# %%
#train = 11
#test = 12           # 23
#validation = 13     # 36

#B(train,test,validation)

# %%
def C(train,test,validation):
    # total C from (22537 to 45946)
    basee = 22537
    pic_want = basee + train      # here type how many pic you want to copy for train data
    #print("base :",basee)
    #print("picwant :",pic_want)
    
    fname_start_from = 0
    pic_size = (28,28)
    dir_path = train_C_dir
    for i in range(basee,pic_want):
        plt.figure(figsize = (pic_size))
        plt.imshow(X.iloc[i].values.reshape(28,28),interpolation='nearest', cmap='Greys')
        filename = 'C.' + str(fname_start_from) +'.jpg'
        path = os.path.join(dir_path, filename)
        plt.savefig(path)
        plt.close()
        fname_start_from+=1

    basee =  pic_want # basee + pic_want
    pic_want = basee + test   # here type how many pic you want to copy for test data
    #print("base :",basee)
    #print("picwant :",pic_want)
    
    fname_start_from = 0
    pic_size = (28,28)
    dir_path = test_C_dir
    for i in range(basee,pic_want):
        plt.figure(figsize = (pic_size))
        plt.imshow(X.iloc[i].values.reshape(28,28),interpolation='nearest', cmap='Greys')
        filename = 'C.' + str(fname_start_from) +'.jpg'
        path = os.path.join(dir_path, filename)
        plt.savefig(path)
        plt.close()
        fname_start_from+=1

    basee =  pic_want # + pic_want
    pic_want = basee + validation      # here type how many pic you want to copy for validation data
    #print("base :",basee)
    #print("picwant :",pic_want)
    
    fname_start_from = 0
    pic_size = (28,28)
    dir_path = validation_C_dir
    for i in range(basee,pic_want):
        plt.figure(figsize = (pic_size))
        plt.imshow(X.iloc[i].values.reshape(28,28),interpolation='nearest', cmap='Greys')
        filename = 'C.' + str(fname_start_from) +'.jpg'
        path = os.path.join(dir_path, filename)
        plt.savefig(path)
        plt.close()
        fname_start_from+=1

# %%
#train = 11
#test = 12           # 23
#validation = 13     # 36

#C(train,test,validation)

# %%
def D(train,test,validation):
    # total D from (45946 to 56079)
    basee = 45946
    pic_want = basee + train
    #print("base :",basee)
    #print("picwant :",pic_want)
    
    fname_start_from = 0
    pic_size = (28,28)
    dir_path = train_D_dir
    for i in range(basee,pic_want):
        plt.figure(figsize = (pic_size))
        plt.imshow(X.iloc[i].values.reshape(28,28),interpolation='nearest', cmap='Greys')
        filename = 'D.' + str(fname_start_from) +'.jpg'
        path = os.path.join(dir_path, filename)
        plt.savefig(path)
        plt.close()
        fname_start_from+=1

    basee =  pic_want
    pic_want = basee + test
    #print("base :",basee)
    #print("picwant :",pic_want)
    
    fname_start_from = 0
    pic_size = (28,28)
    dir_path = test_D_dir
    for i in range(basee,pic_want):
        plt.figure(figsize = (pic_size))
        plt.imshow(X.iloc[i].values.reshape(28,28),interpolation='nearest', cmap='Greys')
        filename = 'D.' + str(fname_start_from) +'.jpg'
        path = os.path.join(dir_path, filename)
        plt.savefig(path)
        plt.close()
        fname_start_from+=1

    basee =  pic_want
    pic_want = basee + validation
    #print("base :",basee)
    #print("picwant :",pic_want)
    
    fname_start_from = 0
    pic_size = (28,28)
    dir_path = validation_D_dir
    for i in range(basee,pic_want):
        plt.figure(figsize = (pic_size))
        plt.imshow(X.iloc[i].values.reshape(28,28),interpolation='nearest', cmap='Greys')
        filename = 'D.' + str(fname_start_from) +'.jpg'
        path = os.path.join(dir_path, filename)
        plt.savefig(path)
        plt.close()
        fname_start_from+=1

# %%
#train = 11
#test = 12           # 23
#validation = 13     # 36

#D(train,test,validation)

# %%
def E(train,test,validation):
    # total E from (56080 to 67519)
    basee = 56080
    pic_want = basee + train
    #print("base :",basee)
    #print("picwant :",pic_want)
    
    fname_start_from = 0
    pic_size = (28,28)
    dir_path = train_E_dir
    for i in range(basee,pic_want):
        plt.figure(figsize = (pic_size))
        plt.imshow(X.iloc[i].values.reshape(28,28),interpolation='nearest', cmap='Greys')
        filename = 'E.' + str(fname_start_from) +'.jpg'
        path = os.path.join(dir_path, filename)
        plt.savefig(path)
        plt.close()
        fname_start_from+=1

    basee =  pic_want
    pic_want = basee + test
    #print("base :",basee)
    #print("picwant :",pic_want)
    
    fname_start_from = 0
    pic_size = (28,28)
    dir_path = test_E_dir
    for i in range(basee,pic_want):
        plt.figure(figsize = (pic_size))
        plt.imshow(X.iloc[i].values.reshape(28,28),interpolation='nearest', cmap='Greys')
        filename = 'E.' + str(fname_start_from) +'.jpg'
        path = os.path.join(dir_path, filename)
        plt.savefig(path)
        plt.close()
        fname_start_from+=1

    basee =  pic_want
    pic_want = basee + validation
    #print("base :",basee)
    #print("picwant :",pic_want)
    
    fname_start_from = 0
    pic_size = (28,28)
    dir_path = validation_E_dir
    for i in range(basee,pic_want):
        plt.figure(figsize = (pic_size))
        plt.imshow(X.iloc[i].values.reshape(28,28),interpolation='nearest', cmap='Greys')
        filename = 'E.' + str(fname_start_from) +'.jpg'
        path = os.path.join(dir_path, filename)
        plt.savefig(path)
        plt.close()
        fname_start_from+=1

# %%
#train = 11
#test = 12           # 23
#validation = 13     # 36

#E(train,test,validation)

# %%
def F(train,test,validation):
    # total F from (67519 to 68682)
    basee = 67520
    pic_want = basee + train
    #print("base :",basee)
    #print("picwant :",pic_want)
    
    fname_start_from = 0
    pic_size = (28,28)
    dir_path = train_F_dir
    for i in range(basee,pic_want):
        plt.figure(figsize = (pic_size))
        plt.imshow(X.iloc[i].values.reshape(28,28),interpolation='nearest', cmap='Greys')
        filename = 'F.' + str(fname_start_from) +'.jpg'
        path = os.path.join(dir_path, filename)
        plt.savefig(path)
        plt.close()
        fname_start_from+=1

    basee =  pic_want
    pic_want = basee + test
    #print("base :",basee)
    #print("picwant :",pic_want)
    
    fname_start_from = 0
    pic_size = (28,28)
    dir_path = test_F_dir
    for i in range(basee,pic_want):
        plt.figure(figsize = (pic_size))
        plt.imshow(X.iloc[i].values.reshape(28,28),interpolation='nearest', cmap='Greys')
        filename = 'F.' + str(fname_start_from) +'.jpg'
        path = os.path.join(dir_path, filename)
        plt.savefig(path)
        plt.close()
        fname_start_from+=1

    basee =  pic_want
    pic_want = basee + validation
    #print("base :",basee)
    #print("picwant :",pic_want)
    
    fname_start_from = 0
    pic_size = (28,28)
    dir_path = validation_F_dir
    for i in range(basee,pic_want):
        plt.figure(figsize = (pic_size))
        plt.imshow(X.iloc[i].values.reshape(28,28),interpolation='nearest', cmap='Greys')
        filename = 'F.' + str(fname_start_from) +'.jpg'
        path = os.path.join(dir_path, filename)
        plt.savefig(path)
        plt.close()
        fname_start_from+=1

# %%
#train = 11
#test = 12           # 23
#validation = 13     # 36

#F(train,test,validation)

# %%
def G(train,test,validation):
    # total G from (68683 to 74444)
    basee = 68683
    pic_want = basee + train
    #print("base :",basee)
    #print("picwant :",pic_want)
    
    fname_start_from = 0
    pic_size = (28,28)
    dir_path = train_G_dir
    for i in range(basee,pic_want):
        plt.figure(figsize = (pic_size))
        plt.imshow(X.iloc[i].values.reshape(28,28),interpolation='nearest', cmap='Greys')
        filename = 'G.' + str(fname_start_from) +'.jpg'
        path = os.path.join(dir_path, filename)
        plt.savefig(path)
        plt.close()
        fname_start_from+=1

    basee =  pic_want
    pic_want = basee + test
    #print("base :",basee)
    #print("picwant :",pic_want)
    
    fname_start_from = 0
    pic_size = (28,28)
    dir_path = test_G_dir
    for i in range(basee,pic_want):
        plt.figure(figsize = (pic_size))
        plt.imshow(X.iloc[i].values.reshape(28,28),interpolation='nearest', cmap='Greys')
        filename = 'G.' + str(fname_start_from) +'.jpg'
        path = os.path.join(dir_path, filename)
        plt.savefig(path)
        plt.close()
        fname_start_from+=1

    basee =  pic_want
    pic_want = basee + validation
    #print("base :",basee)
    #print("picwant :",pic_want)
    
    fname_start_from = 0
    pic_size = (28,28)
    dir_path = validation_G_dir
    for i in range(basee,pic_want):
        plt.figure(figsize = (pic_size))
        plt.imshow(X.iloc[i].values.reshape(28,28),interpolation='nearest', cmap='Greys')
        filename = 'G.' + str(fname_start_from) +'.jpg'
        path = os.path.join(dir_path, filename)
        plt.savefig(path)
        plt.close()
        fname_start_from+=1

# %%
#train = 11
#test = 12           # 23
#validation = 13     # 36

#G(train,test,validation)  # not ok

# %%
def H(train,test,validation):
    # total H from (74445 to 81662)
    basee = 74445
    pic_want = basee + train
    #print("base :",basee)
    #print("picwant :",pic_want)
    
    fname_start_from = 0
    pic_size = (28,28)
    dir_path = train_H_dir
    for i in range(basee,pic_want):
        plt.figure(figsize = (pic_size))
        plt.imshow(X.iloc[i].values.reshape(28,28),interpolation='nearest', cmap='Greys')
        filename = 'H.' + str(fname_start_from) +'.jpg'
        path = os.path.join(dir_path, filename)
        plt.savefig(path)
        plt.close()
        fname_start_from+=1

    basee =  pic_want
    pic_want = basee + test
    #print("base :",basee)
    #print("picwant :",pic_want)
    
    fname_start_from = 0
    pic_size = (28,28)
    dir_path = test_H_dir
    for i in range(basee,pic_want):
        plt.figure(figsize = (pic_size))
        plt.imshow(X.iloc[i].values.reshape(28,28),interpolation='nearest', cmap='Greys')
        filename = 'H.' + str(fname_start_from) +'.jpg'
        path = os.path.join(dir_path, filename)
        plt.savefig(path)
        plt.close()
        fname_start_from+=1

    basee =  pic_want
    pic_want = basee + validation
    #print("base :",basee)
    #print("picwant :",pic_want)
    
    fname_start_from = 0
    pic_size = (28,28)
    dir_path = validation_H_dir
    for i in range(basee,pic_want):
        plt.figure(figsize = (pic_size))
        plt.imshow(X.iloc[i].values.reshape(28,28),interpolation='nearest', cmap='Greys')
        filename = 'H.' + str(fname_start_from) +'.jpg'
        path = os.path.join(dir_path, filename)
        plt.savefig(path)
        plt.close()
        fname_start_from+=1

# %%
#train = 11
#test = 12           # 23
#validation = 13     # 36

#H(train,test,validation)

# %%
def I(train,test,validation):
    # total I from (81663 to 82781)
    basee = 81663
    pic_want = basee + train
    #print("base :",basee)
    #print("picwant :",pic_want)
    
    fname_start_from = 0
    pic_size = (28,28)
    dir_path = train_I_dir
    for i in range(basee,pic_want):
        plt.figure(figsize = (pic_size))
        plt.imshow(X.iloc[i].values.reshape(28,28),interpolation='nearest', cmap='Greys')
        filename = 'I.' + str(fname_start_from) +'.jpg'
        path = os.path.join(dir_path, filename)
        plt.savefig(path)
        plt.close()
        fname_start_from+=1

    basee =  pic_want
    pic_want = basee + test
    #print("base :",basee)
    #print("picwant :",pic_want)
    
    fname_start_from = 0
    pic_size = (28,28)
    dir_path = test_I_dir
    for i in range(basee,pic_want):
        plt.figure(figsize = (pic_size))
        plt.imshow(X.iloc[i].values.reshape(28,28),interpolation='nearest', cmap='Greys')
        filename = 'I.' + str(fname_start_from) +'.jpg'
        path = os.path.join(dir_path, filename)
        plt.savefig(path)
        plt.close()
        fname_start_from+=1

    basee =  pic_want
    pic_want = basee + validation
    #print("base :",basee)
    #print("picwant :",pic_want)
    
    fname_start_from = 0
    pic_size = (28,28)
    dir_path = validation_I_dir
    for i in range(basee,pic_want):
        plt.figure(figsize = (pic_size))
        plt.imshow(X.iloc[i].values.reshape(28,28),interpolation='nearest', cmap='Greys')
        filename = 'I.' + str(fname_start_from) +'.jpg'
        path = os.path.join(dir_path, filename)
        plt.savefig(path)
        plt.close()
        fname_start_from+=1

# %%
#train = 11
#test = 12           # 23
#validation = 13     # 36

#I(train,test,validation)

# %%
def J(train,test,validation):
    # total J from (82782 to 91275)
    basee = 82782
    pic_want = basee + train
    #print("base :",basee)
    #print("picwant :",pic_want)
    
    fname_start_from = 0
    pic_size = (28,28)
    dir_path = train_J_dir
    for i in range(basee,pic_want):
        plt.figure(figsize = (pic_size))
        plt.imshow(X.iloc[i].values.reshape(28,28),interpolation='nearest', cmap='Greys')
        filename = 'J.' + str(fname_start_from) +'.jpg'
        path = os.path.join(dir_path, filename)
        plt.savefig(path)
        plt.close()
        fname_start_from+=1

    basee =  pic_want
    pic_want = basee + test
    #print("base :",basee)
    #print("picwant :",pic_want)
    
    fname_start_from = 0
    pic_size = (28,28)
    dir_path = test_J_dir
    for i in range(basee,pic_want):
        plt.figure(figsize = (pic_size))
        plt.imshow(X.iloc[i].values.reshape(28,28),interpolation='nearest', cmap='Greys')
        filename = 'J.' + str(fname_start_from) +'.jpg'
        path = os.path.join(dir_path, filename)
        plt.savefig(path)
        plt.close()
        fname_start_from+=1

    basee =  pic_want
    pic_want = basee + validation
    #print("base :",basee)
    #print("picwant :",pic_want)
    
    fname_start_from = 0
    pic_size = (28,28)
    dir_path = validation_J_dir
    for i in range(basee,pic_want):
        plt.figure(figsize = (pic_size))
        plt.imshow(X.iloc[i].values.reshape(28,28),interpolation='nearest', cmap='Greys')
        filename = 'J.' + str(fname_start_from) +'.jpg'
        path = os.path.join(dir_path, filename)
        plt.savefig(path)
        plt.close()
        fname_start_from+=1

# %%
#train = 11
#test = 12           # 23
#validation = 13     # 36

#J(train,test,validation)

# %%
def K(train,test,validation):
    # total K from (91276 to 96878)
    basee = 91276
    pic_want = basee + train
    #print("base :",basee)
    #print("picwant :",pic_want)
    
    fname_start_from = 0
    pic_size = (28,28)
    dir_path = train_K_dir
    for i in range(basee,pic_want):
        plt.figure(figsize = (pic_size))
        plt.imshow(X.iloc[i].values.reshape(28,28),interpolation='nearest', cmap='Greys')
        filename = 'K.' + str(fname_start_from) +'.jpg'
        path = os.path.join(dir_path, filename)
        plt.savefig(path)
        plt.close()
        fname_start_from+=1

    basee =  pic_want
    pic_want = basee + test
    #print("base :",basee)
    #print("picwant :",pic_want)
    
    fname_start_from = 0
    pic_size = (28,28)
    dir_path = test_K_dir
    for i in range(basee,pic_want):
        plt.figure(figsize = (pic_size))
        plt.imshow(X.iloc[i].values.reshape(28,28),interpolation='nearest', cmap='Greys')
        filename = 'K.' + str(fname_start_from) +'.jpg'
        path = os.path.join(dir_path, filename)
        plt.savefig(path)
        plt.close()
        fname_start_from+=1

    basee =  pic_want
    pic_want = basee + validation
    #print("base :",basee)
    #print("picwant :",pic_want)
    
    fname_start_from = 0
    pic_size = (28,28)
    dir_path = validation_K_dir
    for i in range(basee,pic_want):
        plt.figure(figsize = (pic_size))
        plt.imshow(X.iloc[i].values.reshape(28,28),interpolation='nearest', cmap='Greys')
        filename = 'K.' + str(fname_start_from) +'.jpg'
        path = os.path.join(dir_path, filename)
        plt.savefig(path)
        plt.close()
        fname_start_from+=1

# %%
#train = 11
#test = 12           # 23
#validation = 13     # 36

#K(train,test,validation)

# %%
def L(train,test,validation):
    # total L from (96879 to 108464)
    basee = 96879
    pic_want = basee + train
    #print("base :",basee)
    #print("picwant :",pic_want)
    
    fname_start_from = 0
    pic_size = (28,28)
    dir_path = train_L_dir
    for i in range(basee,pic_want):
        plt.figure(figsize = (pic_size))
        plt.imshow(X.iloc[i].values.reshape(28,28),interpolation='nearest', cmap='Greys')
        filename = 'L.' + str(fname_start_from) +'.jpg'
        path = os.path.join(dir_path, filename)
        plt.savefig(path)
        plt.close()
        fname_start_from+=1

    basee =  pic_want
    pic_want = basee + test
    #print("base :",basee)
    #print("picwant :",pic_want)
    
    fname_start_from = 0
    pic_size = (28,28)
    dir_path = test_L_dir
    for i in range(basee,pic_want):
        plt.figure(figsize = (pic_size))
        plt.imshow(X.iloc[i].values.reshape(28,28),interpolation='nearest', cmap='Greys')
        filename = 'L.' + str(fname_start_from) +'.jpg'
        path = os.path.join(dir_path, filename)
        plt.savefig(path)
        plt.close()
        fname_start_from+=1

    basee =  pic_want
    pic_want = basee + validation
    #print("base :",basee)
    #print("picwant :",pic_want)
    
    fname_start_from = 0
    pic_size = (28,28)
    dir_path = validation_L_dir
    for i in range(basee,pic_want):
        plt.figure(figsize = (pic_size))
        plt.imshow(X.iloc[i].values.reshape(28,28),interpolation='nearest', cmap='Greys')
        filename = 'L.' + str(fname_start_from) +'.jpg'
        path = os.path.join(dir_path, filename)
        plt.savefig(path)
        plt.close()
        fname_start_from+=1

# %%
#train = 11
#test = 12           
#validation = 13    

#L(train,test,validation)

# %%
def M(train,test,validation):
    # total M from (108465 to 120800)
    basee = 108465
    pic_want = basee + train
    #print("base :",basee)
    #print("picwant :",pic_want)
    
    fname_start_from = 0
    pic_size = (28,28)
    dir_path = train_M_dir
    for i in range(basee,pic_want):
        plt.figure(figsize = (pic_size))
        plt.imshow(X.iloc[i].values.reshape(28,28),interpolation='nearest', cmap='Greys')
        filename = 'M.' + str(fname_start_from) +'.jpg'
        path = os.path.join(dir_path, filename)
        plt.savefig(path)
        plt.close()
        fname_start_from+=1

    basee =  pic_want
    pic_want = basee + test
    #print("base :",basee)
    #print("picwant :",pic_want)
    
    fname_start_from = 0
    pic_size = (28,28)
    dir_path = test_M_dir
    for i in range(basee,pic_want):
        plt.figure(figsize = (pic_size))
        plt.imshow(X.iloc[i].values.reshape(28,28),interpolation='nearest', cmap='Greys')
        filename = 'M.' + str(fname_start_from) +'.jpg'
        path = os.path.join(dir_path, filename)
        plt.savefig(path)
        plt.close()
        fname_start_from+=1

    basee =  pic_want
    pic_want = basee + validation
    #print("base :",basee)
    #print("picwant :",pic_want)
    
    fname_start_from = 0
    pic_size = (28,28)
    dir_path = validation_M_dir
    for i in range(basee,pic_want):
        plt.figure(figsize = (pic_size))
        plt.imshow(X.iloc[i].values.reshape(28,28),interpolation='nearest', cmap='Greys')
        filename = 'M.' + str(fname_start_from) +'.jpg'
        path = os.path.join(dir_path, filename)
        plt.savefig(path)
        plt.close()
        fname_start_from+=1

# %%
#train = 11
#test = 12           
#validation = 13    

#M(train,test,validation)

# %%
def N(train,test,validation):
    # total N from (120801 to 139810)
    basee = 120801
    pic_want = basee + train
    #print("base :",basee)
    #print("picwant :",pic_want)
    
    fname_start_from = 0
    pic_size = (28,28)
    dir_path = train_N_dir
    for i in range(basee,pic_want):
        plt.figure(figsize = (pic_size))
        plt.imshow(X.iloc[i].values.reshape(28,28),interpolation='nearest', cmap='Greys')
        filename = 'N.' + str(fname_start_from) +'.jpg'
        path = os.path.join(dir_path, filename)
        plt.savefig(path)
        plt.close()
        fname_start_from+=1

    basee =  pic_want
    pic_want = basee + test
    #print("base :",basee)
    #print("picwant :",pic_want)
    
    fname_start_from = 0
    pic_size = (28,28)
    dir_path = test_N_dir
    for i in range(basee,pic_want):
        plt.figure(figsize = (pic_size))
        plt.imshow(X.iloc[i].values.reshape(28,28),interpolation='nearest', cmap='Greys')
        filename = 'N.' + str(fname_start_from) +'.jpg'
        path = os.path.join(dir_path, filename)
        plt.savefig(path)
        plt.close()
        fname_start_from+=1

    basee =  pic_want
    pic_want = basee + validation
    #print("base :",basee)
    #print("picwant :",pic_want)
    
    fname_start_from = 0
    pic_size = (28,28)
    dir_path = validation_N_dir
    for i in range(basee,pic_want):
        plt.figure(figsize = (pic_size))
        plt.imshow(X.iloc[i].values.reshape(28,28),interpolation='nearest', cmap='Greys')
        filename = 'N.' + str(fname_start_from) +'.jpg'
        path = os.path.join(dir_path, filename)
        plt.savefig(path)
        plt.close()
        fname_start_from+=1

# %%
#train = 11
#test = 12           
#validation = 13    

#N(train,test,validation)

# %%
def O(train,test,validation):
    # total O from (139811 to 197635)
    basee = 139811
    pic_want = basee + train
    #print("base :",basee)
    #print("picwant :",pic_want)
    
    fname_start_from = 0
    pic_size = (28,28)
    dir_path = train_O_dir
    for i in range(basee,pic_want):
        plt.figure(figsize = (pic_size))
        plt.imshow(X.iloc[i].values.reshape(28,28),interpolation='nearest', cmap='Greys')
        filename = 'O.' + str(fname_start_from) +'.jpg'
        path = os.path.join(dir_path, filename)
        plt.savefig(path)
        plt.close()
        fname_start_from+=1

    basee =  pic_want
    pic_want = basee + test
    #print("base :",basee)
    #print("picwant :",pic_want)
    
    fname_start_from = 0
    pic_size = (28,28)
    dir_path = test_O_dir
    for i in range(basee,pic_want):
        plt.figure(figsize = (pic_size))
        plt.imshow(X.iloc[i].values.reshape(28,28),interpolation='nearest', cmap='Greys')
        filename = 'O.' + str(fname_start_from) +'.jpg'
        path = os.path.join(dir_path, filename)
        plt.savefig(path)
        plt.close()
        fname_start_from+=1

    basee =  pic_want
    pic_want = basee + validation
    #print("base :",basee)
    #print("picwant :",pic_want)
    
    fname_start_from = 0
    pic_size = (28,28)
    dir_path = validation_O_dir
    for i in range(basee,pic_want):
        plt.figure(figsize = (pic_size))
        plt.imshow(X.iloc[i].values.reshape(28,28),interpolation='nearest', cmap='Greys')
        filename = 'O.' + str(fname_start_from) +'.jpg'
        path = os.path.join(dir_path, filename)
        plt.savefig(path)
        plt.close()
        fname_start_from+=1

# %%
#train = 11
#test = 12           
#validation = 13    

#O(train,test,validation)

# %%
def P(train,test,validation):
    # total P from (197636 to 216976)
    basee = 197636
    pic_want = basee + train
    #print("base :",basee)
    #print("picwant :",pic_want)
    
    fname_start_from = 0
    pic_size = (28,28)
    dir_path = train_P_dir
    for i in range(basee,pic_want):
        plt.figure(figsize = (pic_size))
        plt.imshow(X.iloc[i].values.reshape(28,28),interpolation='nearest', cmap='Greys')
        filename = 'P.' + str(fname_start_from) +'.jpg'
        path = os.path.join(dir_path, filename)
        plt.savefig(path)
        plt.close()
        fname_start_from+=1

    basee =  pic_want
    pic_want = basee + test
    #print("base :",basee)
    #print("picwant :",pic_want)
    
    fname_start_from = 0
    pic_size = (28,28)
    dir_path = test_P_dir
    for i in range(basee,pic_want):
        plt.figure(figsize = (pic_size))
        plt.imshow(X.iloc[i].values.reshape(28,28),interpolation='nearest', cmap='Greys')
        filename = 'P.' + str(fname_start_from) +'.jpg'
        path = os.path.join(dir_path, filename)
        plt.savefig(path)
        plt.close()
        fname_start_from+=1

    basee =  pic_want
    pic_want = basee + validation
    #print("base :",basee)
    #print("picwant :",pic_want)
    
    fname_start_from = 0
    pic_size = (28,28)
    dir_path = validation_P_dir
    for i in range(basee,pic_want):
        plt.figure(figsize = (pic_size))
        plt.imshow(X.iloc[i].values.reshape(28,28),interpolation='nearest', cmap='Greys')
        filename = 'P.' + str(fname_start_from) +'.jpg'
        path = os.path.join(dir_path, filename)
        plt.savefig(path)
        plt.close()
        fname_start_from+=1

# %%
#train = 11
#test = 12        
#validation = 13    

#P(train,test,validation)

# %%
def Q(train,test,validation):
    # total Q from (216977 to 222788)
    basee = 216977
    pic_want = basee + train
    #print("base :",basee)
    #print("picwant :",pic_want)
    
    fname_start_from = 0
    pic_size = (28,28)
    dir_path = train_Q_dir
    for i in range(basee,pic_want):
        plt.figure(figsize = (pic_size))
        plt.imshow(X.iloc[i].values.reshape(28,28),interpolation='nearest', cmap='Greys')
        filename = 'Q.' + str(fname_start_from) +'.jpg'
        path = os.path.join(dir_path, filename)
        plt.savefig(path)
        plt.close()
        fname_start_from+=1

    basee =  pic_want
    pic_want = basee + test
    #print("base :",basee)
    #print("picwant :",pic_want)
    
    fname_start_from = 0
    pic_size = (28,28)
    dir_path = test_Q_dir
    for i in range(basee,pic_want):
        plt.figure(figsize = (pic_size))
        plt.imshow(X.iloc[i].values.reshape(28,28),interpolation='nearest', cmap='Greys')
        filename = 'Q.' + str(fname_start_from) +'.jpg'
        path = os.path.join(dir_path, filename)
        plt.savefig(path)
        plt.close()
        fname_start_from+=1

    basee =  pic_want
    pic_want = basee + validation
    #print("base :",basee)
    #print("picwant :",pic_want)
    
    fname_start_from = 0
    pic_size = (28,28)
    dir_path = validation_Q_dir
    for i in range(basee,pic_want):
        plt.figure(figsize = (pic_size))
        plt.imshow(X.iloc[i].values.reshape(28,28),interpolation='nearest', cmap='Greys')
        filename = 'Q.' + str(fname_start_from) +'.jpg'
        path = os.path.join(dir_path, filename)
        plt.savefig(path)
        plt.close()
        fname_start_from+=1

# %%
#train = 11
#test = 12        
#validation = 13    

#Q(train,test,validation)

# %%
def R(train,test,validation):
    # total R from (222789 to 234354)
    basee = 222789
    pic_want = basee + train
    #print("base :",basee)
    #print("picwant :",pic_want)
    
    fname_start_from = 0
    pic_size = (28,28)
    dir_path = train_R_dir
    for i in range(basee,pic_want):
        plt.figure(figsize = (pic_size))
        plt.imshow(X.iloc[i].values.reshape(28,28),interpolation='nearest', cmap='Greys')
        filename = 'R.' + str(fname_start_from) +'.jpg'
        path = os.path.join(dir_path, filename)
        plt.savefig(path)
        plt.close()
        fname_start_from+=1

    basee =  pic_want
    pic_want = basee + test
    #print("base :",basee)
    #print("picwant :",pic_want)
    
    fname_start_from = 0
    pic_size = (28,28)
    dir_path = test_R_dir
    for i in range(basee,pic_want):
        plt.figure(figsize = (pic_size))
        plt.imshow(X.iloc[i].values.reshape(28,28),interpolation='nearest', cmap='Greys')
        filename = 'R.' + str(fname_start_from) +'.jpg'
        path = os.path.join(dir_path, filename)
        plt.savefig(path)
        plt.close()
        fname_start_from+=1

    basee =  pic_want
    pic_want = basee + validation
    #print("base :",basee)
    #print("picwant :",pic_want)
    
    fname_start_from = 0
    pic_size = (28,28)
    dir_path = validation_R_dir
    for i in range(basee,pic_want):
        plt.figure(figsize = (pic_size))
        plt.imshow(X.iloc[i].values.reshape(28,28),interpolation='nearest', cmap='Greys')
        filename = 'R.' + str(fname_start_from) +'.jpg'
        path = os.path.join(dir_path, filename)
        plt.savefig(path)
        plt.close()
        fname_start_from+=1

# %%
#train = 11
#test = 12        
#validation = 13    

#R(train,test,validation)

# %%
def S(train,test,validation):
    # total S from (234355 to 282773)
    basee = 234355
    pic_want = basee + train
    #print("base :",basee)
    #print("picwant :",pic_want)
    
    fname_start_from = 0
    pic_size = (28,28)
    dir_path = train_S_dir
    for i in range(basee,pic_want):
        plt.figure(figsize = (pic_size))
        plt.imshow(X.iloc[i].values.reshape(28,28),interpolation='nearest', cmap='Greys')
        filename = 'S.' + str(fname_start_from) +'.jpg'
        path = os.path.join(dir_path, filename)
        plt.savefig(path)
        plt.close()
        fname_start_from+=1

    basee =  pic_want
    pic_want = basee + test
    #print("base :",basee)
    #print("picwant :",pic_want)
    
    fname_start_from = 0
    pic_size = (28,28)
    dir_path = test_S_dir
    for i in range(basee,pic_want):
        plt.figure(figsize = (pic_size))
        plt.imshow(X.iloc[i].values.reshape(28,28),interpolation='nearest', cmap='Greys')
        filename = 'S.' + str(fname_start_from) +'.jpg'
        path = os.path.join(dir_path, filename)
        plt.savefig(path)
        plt.close()
        fname_start_from+=1

    basee =  pic_want
    pic_want = basee + validation
    #print("base :",basee)
    #print("picwant :",pic_want)
    
    fname_start_from = 0
    pic_size = (28,28)
    dir_path = validation_S_dir
    for i in range(basee,pic_want):
        plt.figure(figsize = (pic_size))
        plt.imshow(X.iloc[i].values.reshape(28,28),interpolation='nearest', cmap='Greys')
        filename = 'S.' + str(fname_start_from) +'.jpg'
        path = os.path.join(dir_path, filename)
        plt.savefig(path)
        plt.close()
        fname_start_from+=1

# %%
#train = 11
#test = 12        
#validation = 13    

#S(train,test,validation)

# %%
def T(train,test,validation):
    # total T from (282774 to 305268)
    basee = 282774
    pic_want = basee + train
    #print("base :",basee)
    #print("picwant :",pic_want)
    
    fname_start_from = 0
    pic_size = (28,28)
    dir_path = train_T_dir
    for i in range(basee,pic_want):
        plt.figure(figsize = (pic_size))
        plt.imshow(X.iloc[i].values.reshape(28,28),interpolation='nearest', cmap='Greys')
        filename = 'T.' + str(fname_start_from) +'.jpg'
        path = os.path.join(dir_path, filename)
        plt.savefig(path)
        plt.close()
        fname_start_from+=1

    basee =  pic_want
    pic_want = basee + test
    #print("base :",basee)
    #print("picwant :",pic_want)
    
    fname_start_from = 0
    pic_size = (28,28)
    dir_path = test_T_dir
    for i in range(basee,pic_want):
        plt.figure(figsize = (pic_size))
        plt.imshow(X.iloc[i].values.reshape(28,28),interpolation='nearest', cmap='Greys')
        filename = 'T.' + str(fname_start_from) +'.jpg'
        path = os.path.join(dir_path, filename)
        plt.savefig(path)
        plt.close()
        fname_start_from+=1

    basee =  pic_want
    pic_want = basee + validation
    #print("base :",basee)
    #print("picwant :",pic_want)
    
    fname_start_from = 0
    pic_size = (28,28)
    dir_path = validation_T_dir
    for i in range(basee,pic_want):
        plt.figure(figsize = (pic_size))
        plt.imshow(X.iloc[i].values.reshape(28,28),interpolation='nearest', cmap='Greys')
        filename = 'T.' + str(fname_start_from) +'.jpg'
        path = os.path.join(dir_path, filename)
        plt.savefig(path)
        plt.close()
        fname_start_from+=1

# %%
#train = 11
#test = 12        
#validation = 13    

#T(train,test,validation)

# %%
def U(train,test,validation):
    # total U from (305269 to 334272)
    basee = 305269
    pic_want = basee + train
    #print("base :",basee)
    #print("picwant :",pic_want)
    
    fname_start_from = 0
    pic_size = (28,28)
    dir_path = train_U_dir
    for i in range(basee,pic_want):
        plt.figure(figsize = (pic_size))
        plt.imshow(X.iloc[i].values.reshape(28,28),interpolation='nearest', cmap='Greys')
        filename = 'U.' + str(fname_start_from) +'.jpg'
        path = os.path.join(dir_path, filename)
        plt.savefig(path)
        plt.close()
        fname_start_from+=1

    basee =  pic_want
    pic_want = basee + test
    #print("base :",basee)
    #print("picwant :",pic_want)
    
    fname_start_from = 0
    pic_size = (28,28)
    dir_path = test_U_dir
    for i in range(basee,pic_want):
        plt.figure(figsize = (pic_size))
        plt.imshow(X.iloc[i].values.reshape(28,28),interpolation='nearest', cmap='Greys')
        filename = 'U.' + str(fname_start_from) +'.jpg'
        path = os.path.join(dir_path, filename)
        plt.savefig(path)
        plt.close()
        fname_start_from+=1

    basee =  pic_want
    pic_want = basee + validation
    #print("base :",basee)
    #print("picwant :",pic_want)
    
    fname_start_from = 0
    pic_size = (28,28)
    dir_path = validation_U_dir
    for i in range(basee,pic_want):
        plt.figure(figsize = (pic_size))
        plt.imshow(X.iloc[i].values.reshape(28,28),interpolation='nearest', cmap='Greys')
        filename = 'U.' + str(fname_start_from) +'.jpg'
        path = os.path.join(dir_path, filename)
        plt.savefig(path)
        plt.close()
        fname_start_from+=1

# %%
#train = 11
#test = 12        
#validation = 13    

#U(train,test,validation)

# %%
def V(train,test,validation):
    # total V from (334273 to 343000)
    basee = 334273
    pic_want = basee + train
    #print("base :",basee)
    #print("picwant :",pic_want)
    
    fname_start_from = 0
    pic_size = (28,28)
    dir_path = train_V_dir
    for i in range(basee,pic_want):
        plt.figure(figsize = (pic_size))
        plt.imshow(X.iloc[i].values.reshape(28,28),interpolation='nearest', cmap='Greys')
        filename = 'V.' + str(fname_start_from) +'.jpg'
        path = os.path.join(dir_path, filename)
        plt.savefig(path)
        plt.close()
        fname_start_from+=1

    basee =  pic_want
    pic_want = basee + test
    #print("base :",basee)
    #print("picwant :",pic_want)
    
    fname_start_from = 0
    pic_size = (28,28)
    dir_path = test_V_dir
    for i in range(basee,pic_want):
        plt.figure(figsize = (pic_size))
        plt.imshow(X.iloc[i].values.reshape(28,28),interpolation='nearest', cmap='Greys')
        filename = 'V.' + str(fname_start_from) +'.jpg'
        path = os.path.join(dir_path, filename)
        plt.savefig(path)
        plt.close()
        fname_start_from+=1

    basee =  pic_want
    pic_want = basee + validation
    #print("base :",basee)
    #print("picwant :",pic_want)
    
    fname_start_from = 0
    pic_size = (28,28)
    dir_path = validation_V_dir
    for i in range(basee,pic_want):
        plt.figure(figsize = (pic_size))
        plt.imshow(X.iloc[i].values.reshape(28,28),interpolation='nearest', cmap='Greys')
        filename = 'V.' + str(fname_start_from) +'.jpg'
        path = os.path.join(dir_path, filename)
        plt.savefig(path)
        plt.close()
        fname_start_from+=1

# %%
#train = 11
#test = 16        
#validation = 13    

#V(train,test,validation)

# %%
def W(train,test,validation):
    # total W from (343001 to 349242)
    basee = 343001
    pic_want = basee + train
    #print("base :",basee)
    #print("picwant :",pic_want)
    
    fname_start_from = 0
    pic_size = (28,28)
    dir_path = train_W_dir
    for i in range(basee,pic_want):
        plt.figure(figsize = (pic_size))
        plt.imshow(X.iloc[i].values.reshape(28,28),interpolation='nearest', cmap='Greys')
        filename = 'W.' + str(fname_start_from) +'.jpg'
        path = os.path.join(dir_path, filename)
        plt.savefig(path)
        plt.close()
        fname_start_from+=1

    basee =  pic_want
    pic_want = basee + test
    #print("base :",basee)
    #print("picwant :",pic_want)
    
    fname_start_from = 0
    pic_size = (28,28)
    dir_path = test_W_dir
    for i in range(basee,pic_want):
        plt.figure(figsize = (pic_size))
        plt.imshow(X.iloc[i].values.reshape(28,28),interpolation='nearest', cmap='Greys')
        filename = 'W.' + str(fname_start_from) +'.jpg'
        path = os.path.join(dir_path, filename)
        plt.savefig(path)
        plt.close()
        fname_start_from+=1

    basee =  pic_want
    pic_want = basee + validation
    #print("base :",basee)
    #print("picwant :",pic_want)
    
    fname_start_from = 0
    pic_size = (28,28)
    dir_path = validation_W_dir
    for i in range(basee,pic_want):
        plt.figure(figsize = (pic_size))
        plt.imshow(X.iloc[i].values.reshape(28,28),interpolation='nearest', cmap='Greys')
        filename = 'W.' + str(fname_start_from) +'.jpg'
        path = os.path.join(dir_path, filename)
        plt.savefig(path)
        plt.close()
        fname_start_from+=1

# %%
#train = 11
#test = 16        
#validation = 13    

#W(train,test,validation)

# %%
def x(train,test,validation):
    # total X from (349243 to 355514)
    basee = 349243
    pic_want = basee + train
    #print("base :",basee)
    #print("picwant :",pic_want)
    
    fname_start_from = 0
    pic_size = (28,28)
    dir_path = train_X_dir
    for i in range(basee,pic_want):
        plt.figure(figsize = (pic_size))
        plt.imshow(X.iloc[i].values.reshape(28,28),interpolation='nearest', cmap='Greys')
        filename = 'X.' + str(fname_start_from) +'.jpg'
        path = os.path.join(dir_path, filename)
        plt.savefig(path)
        plt.close()
        fname_start_from+=1

    basee =  pic_want
    pic_want = basee + test
    #print("base :",basee)
    #print("picwant :",pic_want)
    
    fname_start_from = 0
    pic_size = (28,28)
    dir_path = test_X_dir
    for i in range(basee,pic_want):
        plt.figure(figsize = (pic_size))
        plt.imshow(X.iloc[i].values.reshape(28,28),interpolation='nearest', cmap='Greys')
        filename = 'X.' + str(fname_start_from) +'.jpg'
        path = os.path.join(dir_path, filename)
        plt.savefig(path)
        plt.close()
        fname_start_from+=1

    basee =  pic_want
    pic_want = basee + validation
    #print("base :",basee)
    #print("picwant :",pic_want)
    
    fname_start_from = 0
    pic_size = (28,28)
    dir_path = validation_X_dir
    for i in range(basee,pic_want):
        plt.figure(figsize = (pic_size))
        plt.imshow(X.iloc[i].values.reshape(28,28),interpolation='nearest', cmap='Greys')
        filename = 'X.' + str(fname_start_from) +'.jpg'
        path = os.path.join(dir_path, filename)
        plt.savefig(path)
        plt.close()
        fname_start_from+=1

# %%
#train = 11
#test = 16        
#validation = 13    

#x(train,test,validation)

# %%
def Y(train,test,validation):
    # total Y from (355515 to 366373)
    basee = 355515
    pic_want = basee + train
    #print("base :",basee)
    #print("picwant :",pic_want)
    
    fname_start_from = 0
    pic_size = (28,28)
    dir_path = train_Y_dir
    for i in range(basee,pic_want):
        plt.figure(figsize = (pic_size))
        plt.imshow(X.iloc[i].values.reshape(28,28),interpolation='nearest', cmap='Greys')
        filename = 'Y.' + str(fname_start_from) +'.jpg'
        path = os.path.join(dir_path, filename)
        plt.savefig(path)
        plt.close()
        fname_start_from+=1

    basee =  pic_want
    pic_want = basee + test
    #print("base :",basee)
    #print("picwant :",pic_want)
    
    fname_start_from = 0
    pic_size = (28,28)
    dir_path = test_Y_dir
    for i in range(basee,pic_want):
        plt.figure(figsize = (pic_size))
        plt.imshow(X.iloc[i].values.reshape(28,28),interpolation='nearest', cmap='Greys')
        filename = 'Y.' + str(fname_start_from) +'.jpg'
        path = os.path.join(dir_path, filename)
        plt.savefig(path)
        plt.close()
        fname_start_from+=1

    basee =  pic_want
    pic_want = basee + validation
    #print("base :",basee)
    #print("picwant :",pic_want)
    
    fname_start_from = 0
    pic_size = (28,28)
    dir_path = validation_Y_dir
    for i in range(basee,pic_want):
        plt.figure(figsize = (pic_size))
        plt.imshow(X.iloc[i].values.reshape(28,28),interpolation='nearest', cmap='Greys')
        filename = 'Y.' + str(fname_start_from) +'.jpg'
        path = os.path.join(dir_path, filename)
        plt.savefig(path)
        plt.close()
        fname_start_from+=1

# %%
#train = 11
#test = 16        
#validation = 13    

#Y(train,test,validation)

# %%
def Z(train,test,validation):
    # total Z from (366374 to 372449)
    basee = 366374
    pic_want = basee + train
    #print("base :",basee)
    #print("picwant :",pic_want)
    
    fname_start_from = 0
    pic_size = (28,28)
    dir_path = train_Z_dir
    for i in range(basee,pic_want):
        plt.figure(figsize = (pic_size))
        plt.imshow(X.iloc[i].values.reshape(28,28),interpolation='nearest', cmap='Greys')
        filename = 'Z.' + str(fname_start_from) +'.jpg'
        path = os.path.join(dir_path, filename)
        plt.savefig(path)
        plt.close()
        fname_start_from+=1

    basee =  pic_want
    pic_want = basee + test
    #print("base :",basee)
    #print("picwant :",pic_want)
    
    fname_start_from = 0
    pic_size = (28,28)
    dir_path = test_Z_dir
    for i in range(basee,pic_want):
        plt.figure(figsize = (pic_size))
        plt.imshow(X.iloc[i].values.reshape(28,28),interpolation='nearest', cmap='Greys')
        filename = 'Z.' + str(fname_start_from) +'.jpg'
        path = os.path.join(dir_path, filename)
        plt.savefig(path)
        plt.close()
        fname_start_from+=1

    basee =  pic_want
    pic_want = basee + validation
    #print("base :",basee)
    #print("picwant :",pic_want)
    
    fname_start_from = 0
    pic_size = (28,28)
    dir_path = validation_Z_dir
    for i in range(basee,pic_want):
        plt.figure(figsize = (pic_size))
        plt.imshow(X.iloc[i].values.reshape(28,28),interpolation='nearest', cmap='Greys')
        filename = 'Z.' + str(fname_start_from) +'.jpg'
        path = os.path.join(dir_path, filename)
        plt.savefig(path)
        plt.close()
        fname_start_from+=1

# %%
#train = 11
#test = 16        
#validation = 13    

#Z(train,test,validation)

# %%
#plt.imshow(X.iloc[372449].values.reshape(28,28),interpolation='nearest', cmap='Greys')

# %%
##########################################################

# %%
"""print("Type how many pics you want to save of each categories")
train = int(input("train_images : "))
test = int(input("test_images : "))
validation = int(input("validation_images : "))

A(train,test,validation)
B(train,test,validation)
C(train,test,validation)
D(train,test,validation)
E(train,test,validation)
F(train,test,validation)
G(train,test,validation)
H(train,test,validation)
I(train,test,validation)
J(train,test,validation)
K(train,test,validation)
L(train,test,validation)
M(train,test,validation)
N(train,test,validation)
O(train,test,validation)
P(train,test,validation)
Q(train,test,validation)
R(train,test,validation)
S(train,test,validation)
T(train,test,validation)
U(train,test,validation)
V(train,test,validation)
W(train,test,validation)
x(train,test,validation)
Y(train,test,validation)
Z(train,test,validation)"""
# Out:
# 'print("Type how many pics you want to save of each categories")\ntrain = int(input("train_images : "))\ntest = int(input("test_images : "))\nvalidation = int(input("validation_images : "))\n\nA(train,test,validation)\nB(train,test,validation)\nC(train,test,validation)\nD(train,test,validation)\nE(train,test,validation)\nF(train,test,validation)\nG(train,test,validation)\nH(train,test,validation)\nI(train,test,validation)\nJ(train,test,validation)\nK(train,test,validation)\nL(train,test,validation)\nM(train,test,validation)\nN(train,test,validation)\nO(train,test,validation)\nP(train,test,validation)\nQ(train,test,validation)\nR(train,test,validation)\nS(train,test,validation)\nT(train,test,validation)\nU(train,test,validation)\nV(train,test,validation)\nW(train,test,validation)\nx(train,test,validation)\nY(train,test,validation)\nZ(train,test,validation)'

# %%
print("Type how many pics you want to save of each categories")
train = int(input("train_images : "))
test = int(input("test_images : "))
validation = int(input("validation_images : "))
# Out:
# Type how many pics you want to save of each categories
# train_images : 100
# test_images : 30
# validation_images : 20

# %%
A(train,test,validation)

# %%
B(train,test,validation)
# Out:
# base : 13869
# picwant : 13969

# %%
C(train,test,validation)
# Out:
# base : 22667
# picwant : 22687

# %%
D(train,test,validation)
# Out:
# base : 45946
# picwant : 46046

# %%
E(train,test,validation)

# %%
F(train,test,validation)

# %%
G(train,test,validation)

# %%
H(train,test,validation)

# %%
I(train,test,validation)

# %%
J(train,test,validation)

# %%
K(train,test,validation)

# %%
L(train,test,validation)

# %%
M(train,test,validation)

# %%
N(train,test,validation)

# %%
O(train,test,validation)

# %%
P(train,test,validation)

# %%
Q(train,test,validation)

# %%
R(train,test,validation)

# %%
S(train,test,validation)

# %%
T(train,test,validation)

# %%
U(train,test,validation)

# %%
V(train,test,validation)

# %%
W(train,test,validation)

# %%
x(train,test,validation)

# %%
Y(train,test,validation)

# %%
Z(train,test,validation)
